# %% [markdown]
# <a href="https://colab.research.google.com/github/NailahJames/BTE320_Nailah_James/blob/main/bte320inclassassignments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#---Inputs: Sales and Cogs_pct
sales = input("Enter sales ($): ")
sales = float(sales)


cogs_pct = input("Enter Cost of Goods Sold (%): " )
cogs_pct = float(cogs_pct)

#---Processes: Calculate Actual Cost of Goods Sold
cogs = sales * cogs_pct / 100
grossProfit = sales - cogs


#Output: Display Cogs and Gross Profit
print(f"Cost of Goods Sold: ${cogs}")
print(f"Gross Profit: ${grossProfit}")
# Out:
# Enter sales ($): 12000
# Enter Cost of Goods Sold (%): 40
# Cost of Goods Sold: $4800.0
# Gross Profit: $7200.0

# %%
#---Inputs
taxRate = input("Enter Tax Rate (%): ")
taxRate = float(taxRate)

#---Processes
tax = grossProfit * taxRate / 100
netIncome = grossProfit - tax

#---Output:
print(f"Sales: ${sales}")
print(f"Cost of Goods Sold: ${cogs}")
print(f"Gross Profit: ${grossProfit}")
print(f"Tax: ${tax}")
print(f"Net Income: ${netIncome}")
# Out:
# Enter Tax Rate (%): 30
# Sales: $12000.0
# Cost of Goods Sold: $4800.0
# Gross Profit: $7200.0
# Tax: $2160.0
# Net Income: $5040.0

# %% [markdown]
# Inventory Management Assignemnt

# %%
#---Input
demand = int(input("Enter Demand (units/year): "))
reorder = float(input("Enter Reorder Cost ($/unit): "))
holding = float(input("Enter Holding Cost ($/unit/year): "))

#---Processing
eoq = ((2 * demand * reorder) / holding) ** 0.5

#---Output
print(f"Economic Order Quantity: {eoq} units")
# Out:
# Enter Demand (units/year): 100
# Enter Reorder Cost ($/unit): 1.5
# Enter Holding Cost ($/unit/year): 3
# Economic Order Quantity: 10.0 units

# %% [markdown]
# Numerical Calculator

# %%
# Inputs
x = float(input("Enter a number: "))
y = float(input("Enter another number: "))
operator = input("Enter an operator (+, -, *, /, //, **, %): ")

# Processing
if operator == "+":
    output = x + y
elif operator == "-":
    output = x - y
elif operator == "*":
    output = x * y
elif operator == "/":
    output = x / y
elif operator == "//":
    output = x // y
elif operator == "**":
    output = x ** y
elif operator == "%":
    output = x % y
else:
    output = "Invalid operator"

# Outputs
print(f"Ouput: {output}")
# Out:
# Enter a number: 5
# Enter another number: 5
# Enter an operator (+, -, *, /, //, **, %): *
# Ouput: 25.0

# %% [markdown]
# Parking Garage (For / While Loop)

# %%
print ("Hours   Fee")
print("-------------")

for hour in range(1,9):
  fee = 5 + 2.5 * hour
  if  fee < 10:
    fee = 10.0
  elif fee > 20:
    fee = 20.0
  print(f"{hour}\t${fee}")
# Out:
# Hours   Fee
# -------------
# 1	$10.0
# 2	$10.0
# 3	$12.5
# 4	$15.0
# 5	$17.5
# 6	$20.0
# 7	$20.0
# 8	$20.0

# %% [markdown]
# Movie Theater

# %%
for ad in range (0, 201, 25):
  revenue = 20 * 10 + 10 * 2 * ad ** 0.5
  expenses = 200 + ad
  profit = revenue - expenses
  print(ad, round(profit))
# Out:
# 0 0
# 25 75
# 50 91
# 75 98
# 100 100
# 125 99
# 150 95
# 175 90
# 200 83

# %%
emptyList = []
num = float(input("Enter a number (or 0 to finish): "))

while num != 0:
  emptyList.append(num)
  num = float(input("Enter another number (or 0 to finish): "))
emptyList.sort(reverse=True)
print(emptyList)
# Out:
# Enter a number (or 0 to finish): 5
# Enter another number (or 0 to finish): 8
# Enter another number (or 0 to finish): 1
# Enter another number (or 0 to finish): 6
# Enter another number (or 0 to finish): 3
# Enter another number (or 0 to finish): 0
# [8.0, 6.0, 5.0, 3.0, 1.0]

# %%
import random

print("Welcome to Rock, Paper, Scissors!")

# Start the game loop
while True:
    # Ask if the user wants to play
    play = input("Do you want to play? (yes/no): ").strip().lower()

    if play != "yes":
        print("Thanks for playing! Goodbye 👋")
        break

    # User input
    user_choice = input("Choose rock, paper, or scissors: ").strip().lower()
    if user_choice not in ["rock", "paper", "scissors"]:
        print("Invalid choice. Please try again.")
        continue

    # Computer's random choice
    computer_choice = random.choice(["rock", "paper", "scissors"])
    print(f"The computer chose: {computer_choice}")

    # Determine the winner
    if user_choice == computer_choice:
        print("It's a tie!")
    elif (user_choice == "rock" and computer_choice == "scissors") or \
         (user_choice == "paper" and computer_choice == "rock") or \
         (user_choice == "scissors" and computer_choice == "paper"):
        print("You win! 🎉")
    else:
        print("Computer wins! 🤖")
# Out:
# Welcome to Rock, Paper, Scissors!
# Do you want to play? (yes/no): yes
# Choose rock, paper, or scissors: scissors
# The computer chose: rock
# Computer wins! 🤖
# Do you want to play? (yes/no): yes
# Choose rock, paper, or scissors: paper
# The computer chose: paper
# It's a tie!
# Do you want to play? (yes/no): yes
# Choose rock, paper, or scissors: rock
# The computer chose: scissors
# You win! 🎉
# Do you want to play? (yes/no): no
# Thanks for playing! Goodbye 👋

# %% [markdown]
# Product Prices (Dictionaries)

# %%
products = {
    "P-01": 9.95,
    "P-02": 10.50
    }

userInput = input("Enter product ID: ")

if userInput in products:
  print(f"Product: {userInput}, Price: ${products[userInput]}")
else:
  print("Product not found")
# Out:
# Enter product ID: P-01
# Product: P-01, Price: $9.95

# %% [markdown]
# Parking Garage: calcFree() Function

# %%
def hours(h):
  fee = 5 + 2.5 * h
  if  fee < 10:
    return 10.0
  elif fee > 20:
    return 20.0
  else:
    return fee


def main():
  userHours = int(input("Enter number hours for parking: "))
  fee = hours(userHours)
  print(fee)


if __name__ == "__main__":
  main()
# Out:
# Enter number hours for parking: 3
# 12.5

# %% [markdown]
# Recursive Function: String Reversal

# %%
#Base case is when the is only one letter in something like "hello"
def reverse(s):
  if len(s) > 1:
    return s[-1] + reverse(s[:-1])
  else:
    return s

reverse("hello")
# Out:
# 'olleh'

# %% [markdown]
# 1st Question of Assignment 2 Using Exception Handling

# %%
#---The getValues() funciton will actually get the values from the user
def getValues(n):
  values = []
  for i in range(n):
    value = float(input(f"Enter weight: "))
    values.append(value)
  return values

#---calcAverage() funciton will calulate the the average of the lis tof numbers given by the user
def calcAverage(alist):
  if len(alist) <= 2:
    return 0
  correctList = alist[2:] #This wille xlcude the first two vlaues of the list
  total = sum(correctList)
  average = total / (len(correctList))#Finds the average
  return average

def main():
  number = int(input("How many weights will you enter?: "))
  weights = getValues(number)
  average = calcAverage(weights)
  print(f"The average weight is: {average}")



try:
  if value < 0:
    print("Invalid input. Please enter a positve number")
else:
  print("Processing...")





main()

# %%
#---The getValues() funciton will actually get the values from the user
def getValues(n):
  values = []
  for i in range(n):
    value = float(input(f"Enter weight: "))
    values.append(value)
  #---Handling the exception


  return values

#---calcAverage() funciton will calculate the the average of the lis tof numbers given by the user
def calcAverage(alist):

  try:
    return sum(alist[2:]) / len(alist[2:])
  except Exception as e:
    print(e)
    return float("nan")


def main():
  n = int(input("How many weights will you enter?: "))
  if n < 0:
    raise ValueError("Invalid input. Please enter a positve number")
  L = getValues(n)
  avg = calcAverage(L)
  print(f"The average weight is: {avg}lbs.")

main()
# Out:
# How many weights will you enter?: 2
# Enter weight: 5
# Enter weight: 8
# division by zero
# The average weight is: nanlbs.
